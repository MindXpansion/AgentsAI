# %% [markdown]
# ## crewai
#
# * python 3.10
# * https://medium.com/@sridevi17j/step-by-step-guide-setting-up-and-running-ollama-in-windows-macos-linux-a00f21164bf3
# * https://medium.com/@sahin.samia/building-ai-agents-with-crewai-a-step-by-step-guide-172627e110c5
# * https://docs.crewai.com/concepts/crews
# *  $$ ollama run llama3.2

# %%
## !pip install crewai
## !pip install 'crewai[tools]'

# %%
import os
from crewai_tools import SerperDevTool, BrowserbaseLoadTool, EXASearchTool
from crewai import Agent
from crewai import Task
from crewai import LLM

from langchain_community.llms import Ollama


from crewai import Crew, Process

# %% [markdown]
# ## First Example

# %%
researcher_agent = Agent(
    role="Senior Data Researcher",
    goal="Uncover cutting-edge developments in AI",
    backstory="A seasoned researcher with a knack for uncovering the latest developments in AI.",
    tools=[    SerperDevTool()    ],
    verbose=True
)

# %%
'''
openai_llm = LLM(
    model="gpt-4",
    api_key="your-openai-api-key",
    api_base="https://api.openai.com/v1"
)
'''
# Out:
# '\nopenai_llm = LLM(\n    model="gpt-4",\n    api_key="your-openai-api-key",\n    api_base="https://api.openai.com/v1"\n)\n'

# %%
ollama_llm = LLM(
    model="ollama/llama3.1",
    base_url="http://localhost:11434"
)

# %%
llm_llama = Ollama(model="llama2")
# Out:
# /var/folders/q4/zdsjyw0d297_fn6_fh5n7g9h0000gn/T/ipykernel_79491/1854168522.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm_llama = Ollama(model="llama2")

# %%
researcher_agent = Agent(
    role='Researcher',
    goal='Find and summarize the latest fusion energy news',
    backstory="""You're a researcher at a large company.
    You're responsible for analyzing data and providing insights
    to the business.""",
    verbose=False,
    ## llm=llm_llama
    llm=LLM( model="ollama/llama3.2", base_url="http://localhost:11434" )
)

# %%
'''

os.environ["OPENAI_API_KEY"] = "your-openai-api-key"
os.environ["OPENAI_API_BASE"] = "https://api.openai.com/v1"

'''
# Out:
# '\n\nos.environ["OPENAI_API_KEY"] = "your-openai-api-key"\nos.environ["OPENAI_API_BASE"] = "https://api.openai.com/v1"\n\n'

# %%
from crewai_tools import WebsiteSearchTool

# %%
## task = Task(description=""" Test """, agent = research_agent)

research_task = Task(
    description="Conduct comprehensive research on the latest fusion energy developments.",
    expected_output="A summary report highlighting key advancements in fusion energy that is really funny, with lots of jokes",
    agent=researcher_agent,
    ## tools=[ WebsiteSearchTool() ],
    async_execution=True
)

'''

research_task = Task(
    description="Conduct comprehensive research on the latest AI developments.",
    expected_output="A summary report highlighting key advancements in AI.",
    agent=researcher_agent,
    ## tools=[search_tool],
    async_execution=True
)

'''
# Out:
# '\n\nresearch_task = Task(\n    description="Conduct comprehensive research on the latest AI developments.",\n    expected_output="A summary report highlighting key advancements in AI.",\n    agent=researcher_agent,\n    ## tools=[search_tool],\n    async_execution=True\n)\n\n'

# %%
'''
crew = Crew(
      agents=[research_agent],
      tasks = [research_task],
      verbose=2
)
'''
# Out:
# '\ncrew = Crew(\n      agents=[research_agent],\n      tasks = [research_task],\n      verbose=2\n)\n'

# %%
my_crew = Crew(
    agents=[researcher_agent],
    tasks=[research_task],
    process=Process.sequential,
    verbose=True
)

# %%
result = my_crew.kickoff()
print(result)
# Out:
# # Agent: Researcher
# ## Task: Conduct comprehensive research on the latest fusion energy developments.
#
#
# # Agent: Researcher
# ## Final Answer:
# Here's a summary report highlighting key advancements in fusion energy, with lots of jokes:
#
# Fusion Energy Update
#
# Introduction:
#  Fusion energy - the holy grail of clean energy sources. Who needs unicorns when you have nuclear reactions that release more energy than they consume?
#
# Recent Breakthroughs:
#
# * National Ignition Facility (NIF) achieves record-breaking levels of energy in a high-powered laser-fusion experiment.
# 	+ Why did the scientist take out his doorbell? He wanted to win the no-bell prize! (Sorry, we couldn't resist.)
# * Joint European Torus (JET) makes significant improvements to their tokamak design.
# 	+ What do you call a group of cows playing instruments in space? A moo-sical band! (Okay, maybe that one was a bit of a stretch...)
# * University of California, Los Angeles (UCLA) demonstrates the feasibility of achieving 1.5 megawatt-level fusion power using high-temperature superconducting magnets.
# 	+ Why did the physicist break up with his girlfriend? He found her mass attractive, but her charge was always negative! (Sorry, we know that one was a bit of a dud...)
#
# Future Outlook:
#  Fusion energy is still in its experimental phase, and commercialization will likely take some time. However, with continued research and development, we can expect to see significant advancements in the coming years.
#
# Conclusion:
# In conclusion, fusion energy is like the Energizer Bunny - it keeps going and going and going... until someone comes along and tells it that it's been a long day (just kidding, no one has told the Energizer Bunny that). Seriously though, the latest developments in fusion energy are bringing us closer to harnessing the power of the sun without burning the Earth. Who knows what the future holds? Maybe we'll have fusion-powered cars that don't run out of "gas" anytime soon!
#
#
# Here's a summary report highlighting key advancements in fusion energy, with lots of jokes:
#
# Fusion Energy Update
#
# Introduction:
#  Fusion energy - the holy grail of clean energy sources. Who needs unicorns when you have nuclear reactions that release more energy than they consume?
#
# Recent Breakthroughs:
#
# * National Ignition Facility (NIF) achieves record-breaking levels of energy in a high-powered laser-fusion experiment.
# 	+ Why did the scientist take out his doorbell? He wanted to win the no-bell prize! (Sorry, we couldn't resist.)
# * Joint European Torus (JET) makes significant improvements to their tokamak design.
# 	+ What do you call a group of cows playing instruments in space? A moo-sical band! (Okay, maybe that one was a bit of a stretch...)
# * University of California, Los Angeles (UCLA) demonstrates the feasibility of achieving 1.5 megawatt-level fusion power using high-temperature superconducting magnets.
# 	+ Why did the physicist break up with his girlfriend? He found her mass attractive, but her charge was always negative! (Sorry, we know that one was a bit of a dud...)
#
# Future Outlook:
#  Fusion energy is still in its experimental phase, and commercialization will likely take some time. However, with continued research and development, we can expect to see significant advancements in the coming years.
#
# Conclusion:
# In conclusion, fusion energy is like the Energizer Bunny - it keeps going and going and going... until someone comes along and tells it that it's been a long day (just kidding, no one has told the Energizer Bunny that). Seriously though, the latest developments in fusion energy are bringing us closer to harnessing the power of the sun without burning the Earth. Who knows what the future holds? Maybe we'll have fusion-powered cars that don't run out of "gas" anytime soon!

# %%
print(f"Raw Output: {result.raw}")
# Out:
# Raw Output: Here's a summary report highlighting key advancements in fusion energy, with lots of jokes:
#
# Fusion Energy Update
#
# Introduction:
#  Fusion energy - the holy grail of clean energy sources. Who needs unicorns when you have nuclear reactions that release more energy than they consume?
#
# Recent Breakthroughs:
#
# * National Ignition Facility (NIF) achieves record-breaking levels of energy in a high-powered laser-fusion experiment.
# 	+ Why did the scientist take out his doorbell? He wanted to win the no-bell prize! (Sorry, we couldn't resist.)
# * Joint European Torus (JET) makes significant improvements to their tokamak design.
# 	+ What do you call a group of cows playing instruments in space? A moo-sical band! (Okay, maybe that one was a bit of a stretch...)
# * University of California, Los Angeles (UCLA) demonstrates the feasibility of achieving 1.5 megawatt-level fusion power using high-temperature superconducting magnets.
# 	+ Why did the physicist break up with his girlfriend? He found her mass attractive, but her charge was always negative! (Sorry, we know that one was a bit of a dud...)
#
# Future Outlook:
#  Fusion energy is still in its experimental phase, and commercialization will likely take some time. However, with continued research and development, we can expect to see significant advancements in the coming years.
#
# Conclusion:
# In conclusion, fusion energy is like the Energizer Bunny - it keeps going and going and going... until someone comes along and tells it that it's been a long day (just kidding, no one has told the Energizer Bunny that). Seriously though, the latest developments in fusion energy are bringing us closer to harnessing the power of the sun without burning the Earth. Who knows what the future holds? Maybe we'll have fusion-powered cars that don't run out of "gas" anytime soon!

# %%
'''

liteLLM will automatically connect to the local llm
make sure you local llm is running

## >> ollama run llama3.2

'''
# Out:
# '\n\nliteLLM will automatically connect to the local llm\nmake sure you local llm is running\n\n## >> ollama run llama3.2\n\n'

# %%
import pandas as pd
from crewai import Agent, Task, Crew

from langchain.tools import tool

# %% [markdown]
# ## CSV

# %%
# Load CSV
df = pd.read_csv("sales.csv")

@tool
def summarize_csv() -> str:
    """Summarizes the dataframe by showing the first few rows and statistical metrics."""
    summary = df.describe(include='all').to_string()
    preview = df.head().to_string()
    return f"Data Preview:\n{preview}\n\nSummary Statistics:\n{summary}"

# %%
 
analyst = Agent(
    role='CSV Analyst',
    goal='Read the spreadsheet and summarize key metrics',
    backstory="""You're a researcher at a large company.
    You're responsible for analyzing data and providing insights
    to the business.""",
    verbose=False,
    ## llm=llm_llama
    tools=[   summarize_csv  ],
    llm=LLM( model="ollama/mistral:7b", base_url="http://localhost:11434" )
)

# %%
task = Task(
    description="Summarize the spreadsheet, including any trends or patterns.",
    expected_output="A markdown-style summary report of the dataset including basic statistics and key insights.",
    agent=analyst
)

# %%
# === Crew ===
crew = Crew(agents=[analyst], tasks=[task], verbose=True)

if __name__ == "__main__":
    result = crew.kickoff()
    print("\n--- Summary Report ---\n")
    print(result)
# Out:
# 2025-12-05 00:49:22,822 - 8605147712 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed
# # Agent: CSV Analyst
# ## Task: Summarize the spreadsheet, including any trends or patterns.
#
#
# # Agent: CSV Analyst
# ## Thought: Thought: To begin with, I need to read the CSV file and summarize its key metrics using the `summarize_csv` tool.
# ## Using tool: summarize_csv
# ## Tool Input:
# "{\"file\": \"spreadsheet.csv\"}"
# ## Tool Output:
# Data Preview:
#          Date  Revenue  Expenses  Customers
# 0  2024-01-31    12000      8000        234
# 1  2024-02-29    10000      8500        201
# 2  2024-03-31     9300      8700        198
# 3  2024-04-30    11500      8100        225
# 4  2024-05-31     9800      7900        210
#
# Summary Statistics:
#               Date       Revenue    Expenses   Customers
# count            6      6.000000     6.00000    6.000000
# unique           6           NaN         NaN         NaN
# top     2024-01-31           NaN         NaN         NaN
# freq             1           NaN         NaN         NaN
# mean           NaN  10500.000000  8200.00000  213.833333
# std            NaN   1043.072385   322.49031   13.876839
# min            NaN   9300.000000  7900.00000  198.000000
# 25%            NaN   9850.000000  8000.00000  203.250000
# 50%            NaN  10200.000000  8050.00000  212.500000
# 75%            NaN  11225.000000  8400.00000  222.500000
# max            NaN  12000.000000  8700.00000  234.000000
#
#
# # Agent: CSV Analyst
# ## Final Answer:
# Here is the summary report for the dataset in markdown format:
#
# ```markdown
# ### Data Preview
#
# | Date   | Revenue  | Expenses | Customers |
# |--------|----------|----------|-----------|
# | 2024-01-31 |    12000       | 8000      | 234        |
# | 2024-02-29 |    10000       | 8500      | 201        |
# | 2024-03-31 |     9300       | 8700      | 198        |
# | 2024-04-30 |    11500       | 8100      | 225        |
# | 2024-05-31 |     9800       | 7900      | 210        |
#
# ### Summary Statistics
#
# | Metric                | Description                           | Value   |
# |-----------------------|---------------------------------------|---------|
# | count                 | Number of rows in the dataset         | 6       |
# | unique                | Number of unique values for each column | NaN     |
# | top                   | Most frequent value for each column    | NaN     |
# | freq                  | Frequency of the most common value    | NaN     |
# | mean (Revenue, Expenses) | Average revenue and expenses          | 10500.0, 8200.0  |
# | std (Revenue, Expenses) | Standard deviation for revenue and expenses | 1043.07, 322.49  |
# | min                   | Minimum values for revenue and expenses | 9300.0, 7900.0 |
# | 25%                   | Median of lower half for revenue and expenses| 9850.0, 8000.0 |
# | 50%                   | Median of the entire dataset for revenue and expenses    | 10200.0, 8050.0 |
# | 75%                   | Median of upper half for revenue and expenses | 11225.0, 8400.0 |
# | max                   | Maximum values for revenue and expenses | 12000.0, 8700.0 |
# ```
#
# Observations from the data:
# - Revenue and expenses appear to be positively correlated with a standard deviation of 1043.07 for revenue and 322.49 for expenses.
# - Customers seem to fluctuate between 198 and 234 throughout the dataset, without a clear trend.
# - The average revenue per month is approximately 10500, while the average expenses are around 8200. However, it's important to note that these averages do not account for the differences in the number of days in each month (e.g., February has 29 days while other months have 30 or 31 days).
# - The median revenue and expenses are consistent across the dataset, with values of 10200 and 8050 respectively. This indicates that there may be some outliers in the data (e.g., a very high or low revenue or expense for one month), but the majority of values fall around these median values.
# - The minimum revenue is 9300, while the minimum expenses are 7900. This suggests that there may have been some months where expenses were relatively higher than the average, compared to the revenues. It's important to investigate this further to understand any underlying causes.
#
#
#
# --- Summary Report ---
#
# Here is the summary report for the dataset in markdown format:
#
# ```markdown
# ### Data Preview
#
# | Date   | Revenue  | Expenses | Customers |
# |--------|----------|----------|-----------|
# | 2024-01-31 |    12000       | 8000      | 234        |
# | 2024-02-29 |    10000       | 8500      | 201        |
# | 2024-03-31 |     9300       | 8700      | 198        |
# | 2024-04-30 |    11500       | 8100      | 225        |
# | 2024-05-31 |     9800       | 7900      | 210        |
#
# ### Summary Statistics
#
# | Metric                | Description                           | Value   |
# |-----------------------|---------------------------------------|---------|
# | count                 | Number of rows in the dataset         | 6       |
# | unique                | Number of unique values for each column | NaN     |
# | top                   | Most frequent value for each column    | NaN     |
# | freq                  | Frequency of the most common value    | NaN     |
# | mean (Revenue, Expenses) | Average revenue and expenses          | 10500.0, 8200.0  |
# | std (Revenue, Expenses) | Standard deviation for revenue and expenses | 1043.07, 322.49  |
# | min                   | Minimum values for revenue and expenses | 9300.0, 7900.0 |
# | 25%                   | Median of lower half for revenue and expenses| 9850.0, 8000.0 |
# | 50%                   | Median of the entire dataset for revenue and expenses    | 10200.0, 8050.0 |
# | 75%                   | Median of upper half for revenue and expenses | 11225.0, 8400.0 |
# | max                   | Maximum values for revenue and expenses | 12000.0, 8700.0 |
# ```
#
# Observations from the data:
# - Revenue and expenses appear to be positively correlated with a standard deviation of 1043.07 for revenue and 322.49 for expenses.
# - Customers seem to fluctuate between 198 and 234 throughout the dataset, without a clear trend.
# - The average revenue per month is approximately 10500, while the average expenses are around 8200. However, it's important to note that these averages do not account for the differences in the number of days in each month (e.g., February has 29 days while other months have 30 or 31 days).
# - The median revenue and expenses are consistent across the dataset, with values of 10200 and 8050 respectively. This indicates that there may be some outliers in the data (e.g., a very high or low revenue or expense for one month), but the majority of values fall around these median values.
# - The minimum revenue is 9300, while the minimum expenses are 7900. This suggests that there may have been some months where expenses were relatively higher than the average, compared to the revenues. It's important to investigate this further to understand any underlying causes.
