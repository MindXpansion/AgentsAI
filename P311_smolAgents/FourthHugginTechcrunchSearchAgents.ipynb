# %% [markdown]
# ## AI agents search

# %%
## !pip install smolagents
## !pip install datasets
## !pip install langchain
## !pip install langchain_community

## !pip -q install smolagents
## !pip -q install litellm

# %%
'''

export OPENAI_API_KEY="your_api_key_here"

restart "jupyter notebook" 

echo $OPENAI_API_KEY

openai.api_key = os.getenv("OPENAI_API_KEY")


'''
# Out:
# '\n\nexport OPENAI_API_KEY="your_api_key_here"\n\nrestart "jupyter notebook" \n\necho $OPENAI_API_KEY\n\nopenai.api_key = os.getenv("OPENAI_API_KEY")\n\n\n'

# %%
import os

# %%
## print( os.getenv('HF_TOKEN') )

os.environ['HF_TOKEN'] =  os.getenv('HF_TOKEN')

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool,  InferenceClientModel

# %%
## model =  InferenceClientModel(model_id="Qwen/Qwen2.5-Coder-32B-Instruct")
model = InferenceClientModel("mistralai/Mistral-7B-Instruct-v0.2")

agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model, additional_authorized_imports=['requests', 'bs4'])
# Out:
# /Users/user/opt/anaconda3/envs/py311_agentsAI/lib/python3.11/site-packages/smolagents/default_tools.py:135: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   self.ddgs = DDGS(**kwargs)

# %%
agent.run('What are the latest articles on Techcrunch.com?')
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What are the latest articles on Techcrunch.com?                                                                 │
# │                                                                                                                 │
# ╰─ InferenceClientModel - mistralai/Mistral-7B-Instruct-v0.2 ─────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_query = "latest articles Techcrunch.com"
#   results = web_search(search_query)
#   articles = []
#   for result in results[0].split('\n'):
#    if 'TechCrunch' in result and 'article' in result:
#    articles.append(re.search(':\s(.*)', result).group(0)[1:].strip())
#    print(f'Found {len(articles)} articles.')
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code parsing failed on line 6 due to: IndentationError
#  articles.append(re.search(':\s(.*)', result).group(0)[1:\].strip())
#   ^
# Error: expected an indented block after 'if' statement on line 5 (<unknown>, line 6)
# [Step 1: Duration 7.65 seconds| Input tokens: 1,960 | Output tokens: 121]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_query = "latest articles Techcrunch.com"
#   results = web_search(search_query)
#   articles = [re.search(':\s(.*)', result).group(0)[1:].strip() for result in results[0].split('\n') if
#   'TechCrunch' in result and 'article' in result]
#   print(f'Found {len(articles)} articles.')
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <unknown>:3: DeprecationWarning: invalid escape sequence '\s'
# Execution logs:
# Found 0 articles.
#
# Out: None
# [Step 2: Duration 7.57 seconds| Input tokens: 4,270 | Output tokens: 228]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import json
#   import requests
#
#   techcrunch_api_key = "your_techcrunch_api_key_here"
#   techcrunch_api_url = "https://api.techcrunch.com/api/2/articles/1/latest"
#   headers = {"X-TechCrunch-API-Key": techcrunch_api_key}
#
#   response = requests.get(techcrunch_api_url, headers=headers)
#   latest_articles = json.loads(response.content)
#   print(len(latest_articles))
#
#   latest_article_titles = [article["titleText"] for article in latest_articles]
#   print(latest_article_titles)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Warning to user: Code execution failed due to an unauthorized import - Consider passing said import under
# `additional_authorized_imports` when initializing your CodeAgent.
# Code execution failed at line 'import json' due to: InterpreterError: Import of json is not allowed. Authorized
# imports are: ['bs4', 'itertools', 'requests', 'queue', 'datetime', 'unicodedata', 'collections', 'statistics',
# 'stat', 'time', 're', 'random', 'math'\]
# [Step 3: Duration 10.35 seconds| Input tokens: 6,831 | Output tokens: 394]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import ast
#   import requests
#
#   techcrunch_api_key = "your_techcrunch_api_key_here"
#   techcrunch_api_url = "https://api.techcrunch.com/api/2/articles/1/latest"
#   headers = {"X-TechCrunch-API-Key": techcrunch_api_key}
#
#   response = requests.get(techcrunch_api_url, headers=headers)
#   results = response.content
#   parsed_json = ast.parse(results)
#   articles_data = ast.load(compile(parsed_json.__code__, "<string>", "exec"))
#   articles = articles_data["articles"]
#
#   print(len(articles))
#
#   latest_article_titles = [article["titleText"] for article in articles]
#   print(latest_article_titles)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Warning to user: Code execution failed due to an unauthorized import - Consider passing said import under
# `additional_authorized_imports` when initializing your CodeAgent.
# Code execution failed at line 'import ast' due to: InterpreterError: Import of ast is not allowed. Authorized
# imports are: ['bs4', 'itertools', 'requests', 'queue', 'datetime', 'unicodedata', 'collections', 'statistics',
# 'stat', 'time', 're', 'random', 'math'\]
# [Step 4: Duration 13.01 seconds| Input tokens: 9,828 | Output tokens: 589]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   techcrunch_api_key = "your_techcrunch_api_key_here"
#   techcrunch_api_url = "https://api.techcrunch.com/api/2/articles/1/latest"
#   headers = {"X-TechCrunch-API-Key": techcrunch_api_key}
#   response = requests.get(techcrunch_api_url, headers=headers)
#
#   print(response.status_code)
#   print(len(response.content.split("\n")))
#   print(response.content.split("\n")[-2].split(':')[-1].strip())
#   print(response.content.split("\n")[-1].split(':')[-1].strip())
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code execution failed at line 'response = requests.get(techcrunch_api_url, headers=headers)' due to:
# ConnectionError: HTTPSConnectionPool(host='api.techcrunch.com', port=443): Max retries exceeded with url:
# /api/2/articles/1/latest (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at
# 0x11104f850>: Failed to resolve 'api.techcrunch.com' ([Errno 8\] nodename nor servname provided, or not known)"))
# [Step 5: Duration 10.05 seconds| Input tokens: 13,322 | Output tokens: 751]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#   from bs4 import BeautifulSoup
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url)
#   soup = BeautifulSoup(page.content, 'html.parser')
#
#   latest_articles = soup.find_all("h2", class_="headline")
#   latest_article_urls = [article.find("a")["href"] for article in latest_articles]
#
#   print(len(latest_article_urls))
#
#   for url in latest_article_urls:
#    print(url.split("/")[-1])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 0
#
# Out: None
# [Step 6: Duration 8.88 seconds| Input tokens: 17,296 | Output tokens: 876]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 7 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#   from bs4 import BeautifulSoup
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url)
#   soup = BeautifulSoup(page.content, 'html.parser')
#
#   latest_articles = soup.find_all("h1", class_="stream-headline")
#   latest_article_urls = [article.find("a")["href"] for article in latest_articles]
#
#   print(len(latest_article_urls))
#
#   for url in latest_article_urls:
#    print(url.split("/")[-1])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 0
#
# Out: None
# [Step 7: Duration 9.70 seconds| Input tokens: 21,562 | Output tokens: 1,030]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 8 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import time
#   import re
#   import requests
#   from bs4 import BeautifulSoup
#
#   url = "https://techcrunch.com/"
#   time.sleep(5)  # Add a delay for page loading
#   page = requests.get(url)
#   soup = BeautifulSoup(page.content, 'html.parser')
#
#   latest_articles = soup.find_all("h1", class_="stream-headline")
#   latest_article_urls = [article.find("a")["href"] for article in latest_articles]
#
#   print(len(latest_article_urls))
#
#   for url in latest_article_urls:
#    print(url.split("/")[-1])
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 0
#
# Out: None
# [Step 8: Duration 16.11 seconds| Input tokens: 26,151 | Output tokens: 1,209]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 9 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).text
#   title_pattern = re.compile(r'<h[1-6] class="stream-headline"><a.*?>(.*?)</a>', re.DOTALL)
#   match = title_pattern.search(page)
#
#   if match:
#    latest_article_titles = match.group(1).strip().split("\n")
#    latest_article_urls = [f"https://techcrunch.com{re.search(r'<a.*href="(.*)">', match.group(0)).group(1)}"]
#
#    print(len(latest_article_titles))
#    print(latest_article_titles)
#    print(len(latest_article_urls))
#    print(latest_article_urls)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 0
# Code parsing failed on line 11 due to: SyntaxError
#  latest_article_urls = [f"https://techcrunch.com{re.search(r'<a.*href="(.*)">', match.group(0)).group(1)}"\]
#                                                                         ^
# Error: f-string: unterminated string (<unknown>, line 11)
# [Step 9: Duration 13.30 seconds| Input tokens: 31,105 | Output tokens: 1,441]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 10 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).text
#   title_pattern = re.compile(r'<h[1-6] class="stream-headline"><a.*?>(.*?)</a>', re.DOTALL)
#   match = title_pattern.search(page)
#
#   if match:
#    latest_article_titles = match.group(1).strip().split("\n")
#    latest_article_urls = [re.search(r'<a.*href="(.*)">', match.group(0)).group(1)] * len(latest_article_titles)
#
#    print(len(latest_article_titles))
#    print(latest_article_titles)
#    print(len(latest_article_urls))
#    print(latest_article_urls)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
#
# Out: None
# [Step 10: Duration 11.58 seconds| Input tokens: 36,615 | Output tokens: 1,627]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 11 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).text
#
#   content_start_pattern = re.compile(r'<[h1]\s+.*?<a.*?href="([^"]*)"[^>]*>', re.MULTILINE)
#
#   if content_start_pattern.search(page):
#    article_links = [content_start_pattern.search(page, pos=i).group(1) for i in range(len(page)).steps(120, 120)]
#    article_titles = []
#    for link in article_links:
#    title_pattern = re.compile(r'<[h1|h2][^>]*>(.*?)</[h1|h2]>', re.DOTALL)
#    article_titles.append(title_pattern.search(page.split(link)[1]).group(1))
#
#    print(len(article_titles))
#    print(article_titles)
#    print(len(article_links))
#    print(article_links)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
# Code parsing failed on line 13 due to: IndentationError
#  title_pattern = re.compile(r'<[h1|h2\][^>\]*>(.*?)</[h1|h2\]>', re.DOTALL)
#   ^
# Error: expected an indented block after 'for' statement on line 12 (<unknown>, line 13)
# [Step 11: Duration 14.63 seconds| Input tokens: 42,543 | Output tokens: 1,877]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 12 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).text
#
#   content_start_pattern = re.compile(r'<[h1]\s+.*?<a.*?href="([^"]*)"[^>]*>', re.MULTILINE)
#
#   if content_start_pattern.search(page):
#    article_links = [content_start_pattern.search(page, pos=i).group(1) for i in range(len(page)).steps(120, 120)]
#    article_titles = []
#    for link in article_links:
#    title_match = re.search(r'<[h1|h2][^>]*>(.*?)</[h1|h2]>', page, re.DOTALL)
#    if title_match:
#    article_titles.append(title_match.group(1).strip())
#    else:
#    print(f"Error: No title found for link {link}")
#
#    print(len(article_titles))
#    print(article_titles)
#    print(len(article_links))
#    print(article_links)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
# Code parsing failed on line 13 due to: IndentationError
#  title_match = re.search(r'<[h1|h2\][^>\]*>(.*?)</[h1|h2\]>', page, re.DOTALL)
#   ^
# Error: expected an indented block after 'for' statement on line 12 (<unknown>, line 13)
# [Step 12: Duration 13.83 seconds| Input tokens: 49,085 | Output tokens: 2,092]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 13 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).text
#
#   content_start_pattern = re.compile(r'<[h1]\s+.*?<a.*?href="([^"]*)"[^>]*>', re.MULTILINE)
#
#   if content_start_pattern.search(page):
#    article_links = [content_start_pattern.search(page, pos=i).group(1) for i in range(len(page)).steps(120, 120)]
#    article_titles = []
#    for link in article_links:
#    title_match = re.search(r'<[h1|h2][^>]*>(.*?)</[h1|h2]>', page, re.DOTALL)
#    if title_match:
#    title = title_match.group(1).strip()
#    article_titles.append(title)
#    else:
#    print(f"Error: No title found for link {link}")
#    print(len(article_titles))
#    print(article_titles)
#    print(len(article_links))
#    print(article_links)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
# Code parsing failed on line 13 due to: IndentationError
#  title_match = re.search(r'<[h1|h2\][^>\]*>(.*?)</[h1|h2\]>', page, re.DOTALL)
#   ^
# Error: expected an indented block after 'for' statement on line 12 (<unknown>, line 13)
# [Step 13: Duration 16.78 seconds| Input tokens: 56,228 | Output tokens: 2,322]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 14 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).text
#
#   content_start_pattern = re.compile(r'<[h1]\s+.*?<a.*?href="([^"]*)"[^>]*>', re.MULTILINE)
#
#   if content_start_pattern.search(page):
#    article_links = [content_start_pattern.search(page, pos=i).group(1) for i in range(len(page)).steps(120, 120)]
#    article_titles = []
#    for link in article_links:
#    title_match = re.search(r'<[h1|h2][^>]*>(.*?)</[h1|h2]>', page, re.DOTALL)
#    if title_match:
#    title = title_match.group(1).strip()
#    article_titles.append(title)
#    else:
#    print(f"Error: No title found for link {link}")
#
#    print(len(article_titles))
#    print(article_titles)
#    print(len(article_links))
#    print(article_links)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
# Code parsing failed on line 13 due to: IndentationError
#  title_match = re.search(r'<[h1|h2\][^>\]*>(.*?)</[h1|h2\]>', page, re.DOTALL)
#   ^
# Error: expected an indented block after 'for' statement on line 12 (<unknown>, line 13)
# [Step 14: Duration 15.46 seconds| Input tokens: 63,990 | Output tokens: 2,541]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 15 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).text
#
#   content_start_pattern = re.compile(r'<[h1]\s+.*?<a.*?href="([^"]*)"[^>]*>', re.MULTILINE)
#
#   if content_start_pattern.search(page):
#    article_links = [content_start_pattern.search(page, pos=i).group(1) for i in range(len(page)).steps(120, 120)]
#    article_titles = []
#
#    for link in article_links:
#    title_match = re.search(r'<[h1|h2][^>]*>(.*?)</[h1|h2]>', page, re.DOTALL)
#    if title_match:
#    title = title_match.group(1).strip()
#    article_titles.append(title)
#    else:
#    print(f"Error: No title found for link {link}")
#
#    print(len(article_titles))
#    print(article_titles)
#    print(len(article_links))
#    print(article_links)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
# Code parsing failed on line 14 due to: IndentationError
#  title_match = re.search(r'<[h1|h2\][^>\]*>(.*?)</[h1|h2\]>', page, re.DOTALL)
#   ^
# Error: expected an indented block after 'for' statement on line 13 (<unknown>, line 14)
# [Step 15: Duration 15.15 seconds| Input tokens: 72,361 | Output tokens: 2,766]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 16 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).text
#
#   content_start_pattern = re.compile(r'<[h1]\s+.*?<a.*?href="([^"]*)"[^>]*>', re.MULTILINE)
#
#   if content_start_pattern.search(page):
#    article_links = [content_start_pattern.search(page, pos=i).group(1) for i in range(len(page)).steps(120, 120)]
#    article_titles = []
#
#    for link in article_links:
#    title_match = re.search(r'<[h1|h2][^>]*>(.*?)</[h1|h2]>', page, re.DOTALL)
#    if title_match:
#    title = title_match.group(1).strip()
#    article_titles.append(title)
#    else:
#    print(f"Error: No title found for link {link}")
#
#    print(len(article_titles))
#    print(article_titles)
#    print(len(article_links))
#    print(article_links)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
# Code parsing failed on line 14 due to: IndentationError
#  title_match = re.search(r'<[h1|h2\][^>\]*>(.*?)</[h1|h2\]>', page, re.DOTALL)
#   ^
# Error: expected an indented block after 'for' statement on line 13 (<unknown>, line 14)
# [Step 16: Duration 14.70 seconds| Input tokens: 81,348 | Output tokens: 2,995]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 17 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#   from bs4 import BeautifulSoup
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).content
#   soup = BeautifulSoup(page, 'html.parser')
#   latest_articles = soup.find_all('h2', class_='headline')
#   article_links = []
#   article_titles = []
#
#   if latest_articles:
#    for article in latest_articles:
#    article_title = article.find('a')
#    article_titles.append(article_title.text)
#    article_links.append(article_title['href'])
#
#    print(len(article_titles))
#    print(article_titles)
#    print(len(article_links))
#    print(article_links)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
# Code parsing failed on line 14 due to: IndentationError
#  article_title = article.find('a')
#   ^
# Error: expected an indented block after 'for' statement on line 13 (<unknown>, line 14)
# [Step 17: Duration 12.34 seconds| Input tokens: 90,955 | Output tokens: 3,149]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 18 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#   from bs4 import BeautifulSoup
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).content
#   soup = BeautifulSoup(page, 'html.parser')
#
#   article_links = []
#   article_titles = []
#
#   latest_article = soup.find('h1', {'class': 'headline headline-2'})
#
#   if latest_article:
#    article_title = latest_article.findNext('a')
#    article_titles.append(article_title.get_text())
#    article_links.append(article_title.get('href'))
#
#    while latest_article != None:
#    latest_article = latest_article.findNext('h1', {'class': 'headline headline-2'})
#    if latest_article:
#    article_title = latest_article.findNext('a')
#    article_titles.append(article_title.get_text())
#    article_links.append(article_title.get('href'))
#
#    print(len(article_titles))
#    print(article_titles)
#    print(len(article_links))
#    print(article_links)
#   else:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
# Code parsing failed on line 20 due to: IndentationError
#  latest_article = latest_article.findNext('h1', {'class': 'headline headline-2'})
#   ^
# Error: expected an indented block after 'while' statement on line 19 (<unknown>, line 20)
# [Step 18: Duration 15.77 seconds| Input tokens: 101,007 | Output tokens: 3,356]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 19 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#   from bs4 import BeautifulSoup
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).content
#   soup = BeautifulSoup(page, 'html.parser')
#
#   article_links = []
#   article_titles = []
#
#   article = soup.find('h1', {'class': 'headline headline-2'})
#   while article:
#    article_title = article.findNext('a')
#    article_titles.append(article_title.get_text())
#    article_links.append(article_title.get('href'))
#    article = article.findNext('h1', {'class': 'headline headline-2'})
#
#   print(len(article_titles))
#   print(article_titles)
#   print(len(article_links))
#   print(article_links)
#
#   if not article:
#    print("No latest articles found.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# 0
# []
# 0
# []
# No latest articles found.
#
# Out: None
# [Step 19: Duration 13.19 seconds| Input tokens: 111,646 | Output tokens: 3,528]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 20 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#   import requests
#   from bs4 import BeautifulSoup
#
#   url = "https://techcrunch.com/"
#   page = requests.get(url).content
#   soup = BeautifulSoup(page, 'html.parser')
#
#   article_links = []
#   article_titles = []
#
#   article = soup.find('h1', {'class': 'headline headline-2'})
#   if article is None:
#    article_titles = []
#    article_links = []
#    print("No latest articles found.")
#
#   while article:
#    article_title = article.findNext('a')
#    article_titles.append(article_title.get_text())
#    article_links.append(article_title.get('href'))
#    article = article.findNext('h1', {'class': 'headline headline-2'})
#
#   print(len(article_titles))
#   print(article_titles)
#   print(len(article_links))
#   print(article_links)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# No latest articles found.
# 0
# []
# 0
# []
#
# Out: None
# [Step 20: Duration 13.87 seconds| Input tokens: 122,704 | Output tokens: 3,726]
# Reached max steps.
# [Step 21: Duration 9.26 seconds| Input tokens: 132,342 | Output tokens: 3,876]
# " Unfortunately, the code snippets provided in previous attempts could not successfully extract the latest articles from Techcrunch.com due to various issues, including indentation errors and empty lists being returned even when no articles were found.\n\nTo accurately answer the user's query, we would need a proven and working code snippet that can extract the latest articles from Techcrunch.com's HTML content. As this has not been achieved yet, I cannot provide an answer to the user's task based on the given information.\n\nI recommend trying an alternative method for scraping the latest articles from Techcrunch.com using a well-documented and tested code snippet or library. Once such a method is confirmed to work consistently, we can then use it to provide an answer to the user's query."
